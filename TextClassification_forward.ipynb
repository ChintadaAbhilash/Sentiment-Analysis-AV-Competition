# %% [markdown]
# **Analyzing Add on Data**

# %%
import pandas as pd

Add_on = pd.read_csv("/content/add_on_tweets.csv")

Add_on.head()
# Out:
#                username                                               text
# 0          Counter Foul  #aafaque_ehsens_ideamines_sites #ideamines_shs...
# 1  Daily #Nigeria #News  Buhari cancels planned trip to Niger http://dl...
# 2     Scoop Rocket News  2017 Porsche 718 Boxster Expert Review Car Rev...
# 3      Zbigniew Zarnoch  Unique #gift for this unique #time of the #yea...
# 4   Progressive Liberal  Morning Joe Panel Laughs Uproariously Over Lat...

# %%
Add_on.isnull().any()
# Out:
# username    False
# text         True
# dtype: bool

# %%
Add_on.isnull().sum()
# Out:
# username    0
# text        4
# dtype: int64

# %%
Add_on.shape
# Out:
# (40694, 2)

# %% [markdown]
# There are only 4 null values , we can drop the whole row with no issues

# %%
Add_on = Add_on.dropna()

# %%
Add_on.shape  # and GONE !!!!
# Out:
# (40690, 2)

# %% [markdown]
# **Text Processing**

# %%
import nltk

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
import sys
from nltk.stem.porter import PorterStemmer

porter_stemmer = PorterStemmer()

def preprocess_word(word):
    word = word.strip('\'"?!,.():;')
    word = re.sub(r'(.)\1+', r'\1\1', word)
    word = re.sub(r'(-|\')', '', word)
    return word

def is_valid_word(word):
    return (re.search(r'^[a-zA-Z][a-z0-9A-Z\._]*$', word) is not None)

def handle_emojis(tweet):
    tweet = re.sub(r'(:\s?\)|:-\)|\(\s?:|\(-:|:\'\))', ' EMO_POS ', tweet)
    tweet = re.sub(r'(:\s?D|:-D|x-?D|X-?D)', ' EMO_POS ', tweet)
    tweet = re.sub(r'(<3|:\*)', ' EMO_POS ', tweet)
    tweet = re.sub(r'(;-?\)|;-?D|\(-?;)', ' EMO_POS ', tweet)
    tweet = re.sub(r'(:\s?\(|:-\(|\)\s?:|\)-:)', ' EMO_NEG ', tweet)
    tweet = re.sub(r'(:,\(|:\'\(|:"\()', ' EMO_NEG ', tweet)
    return tweet

def preprocess_tweet(tweet):
    use_stemmer = True
    processed_tweet = []
    tweet = tweet.lower()
    tweet = re.sub(r'((www\.[\S]+)|(https?://[\S]+))', ' URL ', tweet)
    tweet = re.sub(r'@[\S]+', 'USER_MENTION', tweet)
    tweet = re.sub(r'#(\S+)', r' \1 ', tweet)
    tweet = re.sub(r'\brt\b', '', tweet)
    tweet = re.sub(r'\.{2,}', ' ', tweet)
    tweet = tweet.strip(' "\'')
    tweet = handle_emojis(tweet)
    tweet = re.sub(r'\s+', ' ', tweet)
    words = tweet.split()
    for word in words:
        word = preprocess_word(word)
        if is_valid_word(word):
            if use_stemmer:
                word = str(porter_stemmer.stem(word))
            processed_tweet.append(word)
    return ' '.join(processed_tweet)

puncts = [',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&', '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£',
 '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',  '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…', '\n', '\xa0', '\t',
 '“', '★', '”', '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾', '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', '\u3000', '\u202f',
 '▒', '：', '¼', '⊕', '▼', '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲', 'è', '¸', '¾', 'Ã', '⋅', '‘', '∞', '«',
 '∙', '）', '↓', '、', '│', '（', '»', '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø', '¹', '≤', '‡', '√', ]
mispell_dict = {"aren't" : "are not",
    "can't" : "cannot",
    "couldn't" : "could not",
    "couldnt" : "could not",
    "didn't" : "did not",
    "doesn't" : "does not",
    "doesnt" : "does not",
    "don't" : "do not",
    "hadn't" : "had not",
    "hasn't" : "has not",
    "haven't" : "have not",
    "havent" : "have not",
    "he'd" : "he would",
    "he'll" : "he will",
    "he's" : "he is",
    "i'd" : "I would",
    "i'd" : "I had",
    "i'll" : "I will",
    "i'm" : "I am",
    "isn't" : "is not",
    "it's" : "it is",
    "it'll":"it will",
    "i've" : "I have",
    "let's" : "let us",
    "mightn't" : "might not",
    "mustn't" : "must not",
    "shan't" : "shall not",
    "she'd" : "she would",
    "she'll" : "she will",
    "she's" : "she is",
    "shouldn't" : "should not",
    "shouldnt" : "should not",
    "that's" : "that is",
    "thats" : "that is",
    "there's" : "there is",
    "theres" : "there is",
    "they'd" : "they would",
    "they'll" : "they will",
    "they're" : "they are",
    "theyre":  "they are",
    "they've" : "they have",
    "we'd" : "we would",
    "we're" : "we are",
    "weren't" : "were not",
    "we've" : "we have",
    "what'll" : "what will",
    "what're" : "what are",
    "what's" : "what is",
    "what've" : "what have",
    "where's" : "where is",
    "who'd" : "who would",
    "who'll" : "who will",
    "who're" : "who are",
    "who's" : "who is",
    "who've" : "who have",
    "won't" : "will not",
    "wouldn't" : "would not",
    "you'd" : "you would",
    "you'll" : "you will",
    "you're" : "you are",
    "you've" : "you have",
    "'re": " are",
    "wasn't": "was not",
    "we'll":" will",
    "didn't": "did not",
    "tryin'":"trying"
    }


def clean_text(x):
    x = str(x)
    for punct in puncts:
        x = x.replace(punct, f' {punct} ')
    return x


def clean_numbers(x):
    x = re.sub('[0-9]{5,}', '#####', x)
    x = re.sub('[0-9]{4}', '####', x)
    x = re.sub('[0-9]{3}', '###', x)
    x = re.sub('[0-9]{2}', '##', x)
    return x


def _get_mispell(mispell_dict):
    mispell_re = re.compile('(%s)' % '|'.join(mispell_dict.keys()))
    return mispell_dict, mispell_re


def replace_typical_misspell(text):
    mispellings, mispellings_re = _get_mispell(mispell_dict)

    def replace(match):
        return mispellings[match.group(0)]

    return mispellings_re.sub(replace, text)


def clean_data(df, columns: list):
    for col in columns:
        df[col] = df[col].apply(lambda x: clean_numbers(x))
        df[col] = df[col].apply(lambda x: clean_text(x.lower()))
        df[col] = df[col].apply(lambda x: replace_typical_misspell(x))

    return df

# %% [markdown]
# **Bulding Language Model**

# %%
from fastai import *
from fastai.text import *

# %%
import pandas as pd

Train = pd.read_csv("/content/train_2kmZucJ_text.csv")
Test = pd.read_csv("/content/test_oJQbWVk_text.csv")

Final = pd.concat([Train , Test , Add_on] , axis = 0 , sort =False)

# %%
Final.head()
# Out:
#     id  label                                               text username
# 0  1.0    0.0  #fingerprint #Pregnancy Test https://goo.gl/h1...      NaN
# 1  2.0    0.0  Finally a transparant silicon case ^^ Thanks t...      NaN
# 2  3.0    0.0  We love this! Would you go? #talk #makememorie...      NaN
# 3  4.0    0.0  I'm wired I know I'm George I was made that wa...      NaN
# 4  5.0    1.0  What amazing service! Apple won't even talk to...      NaN

# %%
Final.tail()
# Out:
#        id  label                                               text    username
# 40689 NaN    NaN  Suivez la suite de la 9e journée du #CHFP2019 ...    FootKole
# 40690 NaN    NaN  WIN 2 Odds Daily & 1.5+ Odds Daily\nJoin us- h...   Featgames
# 40691 NaN    NaN  WIN 2 Odds Daily & 1.5+ Odds Daily\nJoin us- h...   Featgames
# 40692 NaN    NaN  So, not a fan of ESPN sports app for my go to ...  Bobby Sero
# 40693 NaN    NaN  #HBD #TonyDorsett #formerNFL #Football #RB #Co...     Da'Game

# %%
Final = Final.fillna(0)

# %%
# %time Final['text'] = Final['text'].apply(lambda x : preprocess_tweet(x))
# Out:
# CPU times: user 20.6 s, sys: 14 ms, total: 20.7 s
# Wall time: 20.7 s

# %%
Final = clean_data(Final , ['text'])

# %%
Final.shape
# Out:
# (50563, 4)

# %%
Final.head()
# Out:
#     id  label                                               text username
# 0  1.0    0.0  fingerprint pregnanc test url android app beau...        0
# 1  2.0    0.0  final a transpar silicon case thank to my uncl...        0
# 2  3.0    0.0  we love thi would you go talk makememori unplu...        0
# 3  4.0    0.0  im wire i know im georg i wa made that way emo...        0
# 4  5.0    1.0  what amaz servic appl wont even talk to me abo...        0

# %%
#, label_cols = 'label'

#data_lm = TextLMDataBunch.from_df(path = './', train_df = Final , valid_df = Final , text_cols = 'text')

# %%
bs = 128

data_lm = (TextList.from_df(Final, path = './', cols='text')
    .split_by_rand_pct(0.1, seed=42)
    .label_for_lm()
    .databunch(bs=bs, num_workers=1))

# %%
data_lm.save('data_lm_export.pkl')

# %%
data_lm = load_data('./', 'data_lm_export.pkl')

# %%
learn_lm = language_model_learner(data_lm, AWD_LSTM, drop_mult=1.0)

# %%
lr = 1e-3
lr *= bs/48

# %%
learn_lm.fit_one_cycle(3, lr*10, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.845404</td>
#       <td>5.263926</td>
#       <td>0.226200</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.326172</td>
#       <td>4.931391</td>
#       <td>0.251507</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.937075</td>
#       <td>4.822216</td>
#       <td>0.261058</td>
#       <td>00:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_lm.unfreeze()
learn_lm.fit_one_cycle(4, lr, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.629325</td>
#       <td>4.658884</td>
#       <td>0.280069</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.426744</td>
#       <td>4.453678</td>
#       <td>0.307561</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.134580</td>
#       <td>4.347000</td>
#       <td>0.323214</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.927328</td>
#       <td>4.334609</td>
#       <td>0.325465</td>
#       <td>00:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_lm.save('fine_tuned_fwd')
learn_lm.save_encoder('fine_tuned_enc_fwd')

# %% [markdown]
# **Building Classifier**

# %%
#Train['text'] = Train['text'].apply(lambda x : preprocess_tweet(x))

# %%
data_clas = (TextList.from_df(Train, './', vocab=data_lm.vocab, cols='text')
    .split_by_rand_pct(0.1, seed=42)
    .label_from_df(cols='label')
    .databunch(bs=bs, num_workers=1))

# %%
data_clas.vocab.itos = data_lm.vocab.itos

# %%
data_clas.save('data_clas_export.pkl')

# %%
data_clas = load_data('./', 'data_clas_export.pkl', bs=bs, num_workers=1)

# %%
learn_cls = text_classifier_learner(data_clas, AWD_LSTM, drop_mult=0.5).to_fp16()
learn_cls.load_encoder('fine_tuned_enc_fwd')
learn_cls.freeze()

# %%
lr=2e-2
lr *= bs/48

# %%
learn_cls.fit_one_cycle(2, lr, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.460814</td>
#       <td>0.258531</td>
#       <td>0.887626</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.448675</td>
#       <td>0.281979</td>
#       <td>0.868687</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_cls.freeze_to(-2)
learn_cls.fit_one_cycle(2, slice(lr/(2.6**4),lr), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.448107</td>
#       <td>0.280352</td>
#       <td>0.906566</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.394234</td>
#       <td>0.225667</td>
#       <td>0.905303</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_cls.save("1st")

# %%
learn_cls.freeze_to(-3)
learn_cls.fit_one_cycle(2, slice(lr/2/(2.6**4),lr/2), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.392992</td>
#       <td>0.510586</td>
#       <td>0.848485</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.348136</td>
#       <td>0.240741</td>
#       <td>0.910354</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_cls.save("2nd")

# %%
learn_cls.load("2nd")
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (7128 items)
# x: TextList
# xxbos # fingerprint # xxmaj xxunk xxmaj test xxunk xxunk xxunk xxunk xxunk xxunk xxunk # android # xxunk # beautiful # cute # health # xxunk # xxunk # iphonesia # iphone,xxbos xxmaj xxunk a xxunk silicon case xxunk xxmaj xxunk to my xxunk xxunk # yay # xxmaj xxunk # xxmaj xperia # s # xxunk xxunk http xxunk xxunk xxunk xxunk xxunk p xxunk xxunk xxunk,xxbos xxmaj we love xxunk xxunk xxmaj would you go xxunk # talk # xxunk # unplug # relax # iphone # xxunk # wifi # connect xxunk http xxunk xxunk xxunk xxunk xxunk xxunk,xxbos i xxunk xxunk i know i xxunk xxmaj xxunk i was made that way xxunk # iphone # cute # xxunk # home http xxunk xxunk xxunk xxunk xxunk p xxunk xxunk xxunk,xxbos xxmaj what xxunk xxunk xxunk xxmaj apple wo xxunk even talk to me about a question i have unless i pay them xxunk xxunk for their stupid support xxunk
# y: CategoryList
# 0,0,0,0,1
# Path: .;
#
# Valid: LabelList (792 items)
# x: TextList
# xxbos xxmaj photo xxunk xxunk we both xxunk up today xxunk # boyfriend # xxunk # cute # iphone # school # instagood xxunk http xxunk xxunk xxunk xxunk xxunk xxunk,xxbos xxunk your product is brutal xxunk 1 xxunk xxunk xxunk xxunk . xxmaj get it xxunk # xxmaj xxunk ftw,xxbos xxmaj sunset xxmaj today in xxmaj zeeland xxunk xxmaj samsung xxmaj mobile xxup s4 # samsung # sunset # zeeland # xxunk # wave # xxunk xxunk xxunk,xxbos xxmaj god xxunk xxunk xxunk xxunk # it xxunk share xxunk xxunk xxunk xxmaj xxunk my xxunk xxunk that i want to upload # xxunk # not # xxunk # ps4 # xxunk,xxbos xxmaj awe he xxunk da xxunk xxunk # boyfriend him # xxunk # cute # xxunk # xxunk # xxunk # iphone http xxunk xxunk xxunk xxunk xxunk p xxunk xxunk xxunk
# y: CategoryList
# 0,1,0,0,0
# Path: .;
#
# Test: None, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(17224, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(17224, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7fe28c1d60d0>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (7128 items)
# x: TextList
# xxbos # fingerprint # xxmaj xxunk xxmaj test xxunk xxunk xxunk xxunk xxunk xxunk xxunk # android # xxunk # beautiful # cute # health # xxunk # xxunk # iphonesia # iphone,xxbos xxmaj xxunk a xxunk silicon case xxunk xxmaj xxunk to my xxunk xxunk # yay # xxmaj xxunk # xxmaj xperia # s # xxunk xxunk http xxunk xxunk xxunk xxunk xxunk p xxunk xxunk xxunk,xxbos xxmaj we love xxunk xxunk xxmaj would you go xxunk # talk # xxunk # unplug # relax # iphone # xxunk # wifi # connect xxunk http xxunk xxunk xxunk xxunk xxunk xxunk,xxbos i xxunk xxunk i know i xxunk xxmaj xxunk i was made that way xxunk # iphone # cute # xxunk # home http xxunk xxunk xxunk xxunk xxunk p xxunk xxunk xxunk,xxbos xxmaj what xxunk xxunk xxunk xxmaj apple wo xxunk even talk to me about a question i have unless i pay them xxunk xxunk for their stupid support xxunk
# y: CategoryList
# 0,0,0,0,1
# Path: .;
#
# Valid: LabelList (792 items)
# x: TextList
# xxbos xxmaj photo xxunk xxunk we both xxunk up today xxunk # boyfriend # xxunk # cute # iphone # school # instagood xxunk http xxunk xxunk xxunk xxunk xxunk xxunk,xxbos xxunk your product is brutal xxunk 1 xxunk xxunk xxunk xxunk . xxmaj get it xxunk # xxmaj xxunk ftw,xxbos xxmaj sunset xxmaj today in xxmaj zeeland xxunk xxmaj samsung xxmaj mobile xxup s4 # samsung # sunset # zeeland # xxunk # wave # xxunk xxunk xxunk,xxbos xxmaj god xxunk xxunk xxunk xxunk # it xxunk share xxunk xxunk xxunk xxmaj xxunk my xxunk xxunk that i want to upload # xxunk # not # xxunk # ps4 # xxunk,xxbos xxmaj awe he xxunk da xxunk xxunk # boyfriend him # xxunk # cute # xxunk # xxunk # xxunk # iphone http xxunk xxunk xxunk xxunk xxunk p xxunk xxunk xxunk
# y: CategoryList
# 0,1,0,0,0
# Path: .;
#
# Test: None, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(17224, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(17224, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7fe28c1d60d0>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(17224, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(17224, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )], add_time=True, silent=False)
# alpha: 2.0
# beta: 1.0, MixedPrecision
# learn: RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (7128 items)
# x: TextList
# xxbos # fingerprint # xxmaj xxunk xxmaj test xxunk xxunk xxunk xxunk xxunk xxunk xxunk # android # xxunk # beautiful # cute # health # xxunk # xxunk # iphonesia # iphone,xxbos xxmaj xxunk a xxunk silicon case xxunk xxmaj xxunk to my xxunk xxunk # yay # xxmaj xxunk # xxmaj xperia # s # xxunk xxunk http xxunk xxunk xxunk xxunk xxunk p xxunk xxunk xxunk,xxbos xxmaj we love xxunk xxunk xxmaj would you go xxunk # talk # xxunk # unplug # relax # iphone # xxunk # wifi # connect xxunk http xxunk xxunk xxunk xxunk xxunk xxunk,xxbos i xxunk xxunk i know i xxunk xxmaj xxunk i was made that way xxunk # iphone # cute # xxunk # home http xxunk xxunk xxunk xxunk xxunk p xxunk xxunk xxunk,xxbos xxmaj what xxunk xxunk xxunk xxmaj apple wo xxunk even talk to me about a question i have unless i pay them xxunk xxunk for their stupid support xxunk
# y: CategoryList
# 0,0,0,0,1
# Path: .;
#
# Valid: LabelList (792 items)
# x: TextList
# xxbos xxmaj photo xxunk xxunk we both xxunk up today xxunk # boyfriend # xxunk # cute # iphone # school # instagood xxunk http xxunk xxunk xxunk xxunk xxunk xxunk,xxbos xxunk your product is brutal xxunk 1 xxunk xxunk xxunk xxunk . xxmaj get it xxunk # xxmaj xxunk ftw,xxbos xxmaj sunset xxmaj today in xxmaj zeeland xxunk xxmaj samsung xxmaj mobile xxup s4 # samsung # sunset # zeeland # xxunk # wave # xxunk xxunk xxunk,xxbos xxmaj god xxunk xxunk xxunk xxunk # it xxunk share xxunk xxunk xxunk xxmaj xxunk my xxunk xxunk that i want to upload # xxunk # not # xxunk # ps4 # xxunk,xxbos xxmaj awe he xxunk da xxunk xxunk # boyfriend him # xxunk # cute # xxunk # xxunk # xxunk # iphone http xxunk xxunk xxunk xxunk xxunk p xxunk xxunk xxunk
# y: CategoryList
# 0,1,0,0,0
# Path: .;
#
# Test: None, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(17224, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(17224, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7fe28c1d60d0>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(17224, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(17224, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )], add_time=True, silent=False)
# loss_scale: 16384.0
# max_noskip: 1000
# dynamic: True
# clip: None
# flat_master: False
# max_scale: 16777216
# loss_fp32: True], layer_groups=[Sequential(
#   (0): Embedding(17224, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(17224, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )], add_time=True, silent=False)

# %%
learn_cls.freeze_to(-4)
learn_cls.fit_one_cycle(4, slice(lr/3/(2.6**4),lr/2), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.330345</td>
#       <td>0.252410</td>
#       <td>0.900253</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.325304</td>
#       <td>0.272498</td>
#       <td>0.904040</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.245802</td>
#       <td>0.237148</td>
#       <td>0.904040</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.177711</td>
#       <td>0.252249</td>
#       <td>0.905303</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_cls.save("3rd")

# %%
learn_cls.unfreeze()
learn_cls.fit_one_cycle(8, slice(lr/4/(2.6**4),lr/10), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.255088</td>
#       <td>0.229717</td>
#       <td>0.906566</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.238522</td>
#       <td>0.234246</td>
#       <td>0.907828</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.233657</td>
#       <td>0.237318</td>
#       <td>0.911616</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.186932</td>
#       <td>0.289928</td>
#       <td>0.901515</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.134729</td>
#       <td>0.318431</td>
#       <td>0.896465</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.092766</td>
#       <td>0.314527</td>
#       <td>0.900253</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.068748</td>
#       <td>0.343741</td>
#       <td>0.901515</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.053477</td>
#       <td>0.339279</td>
#       <td>0.901515</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Above step clearly overfitted

# %% [markdown]
# **Anyways Lets get down to our  submission**

# %%
learn_cls = learn_cls.load("3rd")

# %%
Tes_ = pd.read_csv("/content/test_oJQbWVk_text.csv")

Tes_.head()
# Out:
#      id                                               text
# 0  7921  I hate the new #iphone upgrade. Won't let me d...
# 1  7922  currently shitting my fucking pants. #apple #i...
# 2  7923  I'd like to puts some CD-ROMS on my iPad, is t...
# 3  7924  My ipod is officially dead. I lost all my pict...
# 4  7925  Been fighting iTunes all night! I only want th...

# %%
Tes_['text'] = Tes_['text'].apply(lambda x : preprocess_tweet(x))
Tes_ = clean_data(Tes_ , ['text'])

# %%
from tqdm import tqdm

predictions = []

for i in tqdm(list(Tes_.text.values)):
    predictions.append(int(learn_cls.predict(i)[1]))
# Out:
# 100%|██████████| 1953/1953 [01:41<00:00, 19.27it/s]

# %%
submission = {'id' : list(Tes_.id.values) , 'label' : predictions}

# %%
Df = pd.DataFrame.from_dict(submission)

# %%
Df.to_csv("submission.csv" , header = True , index = False)
